#    creating: font_recognition/fonts/Sans Collegiate One/
#   inflating: font_recognition/fonts/Sans Collegiate One/AlumniSansCollegiateOne-Regular.ttf
#   inflating: font_recognition/fonts/Sans Collegiate One/AlumniSansCollegiateOne-Italic.ttf
#   inflating: font_recognition/fonts/Sans Collegiate One/OFL.txt
#   inflating: font_recognition/fonts/Sans Collegiate One/COPYRIGHT.txt
#   inflating: font_recognition/fonts/Sans Collegiate One/LICENSE.txt
#    creating: font_recognition/fonts/Aref Ruqaa Ink/
#   inflating: font_recognition/fonts/Aref Ruqaa Ink/ArefRuqaaInk-Regular.ttf
#   inflating: font_recognition/fonts/Aref Ruqaa Ink/ArefRuqaaInk-Bold.ttf
#   inflating: font_recognition/fonts/Aref Ruqaa Ink/OFL.txt
#   inflating: font_recognition/fonts/Aref Ruqaa Ink/COPYRIGHT.txt
#   inflating: font_recognition/fonts/Aref Ruqaa Ink/LICENSE.txt

# %%
# !pip install pillow fonttools
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Requirement already satisfied: fonttools in /usr/local/lib/python3.10/dist-packages (4.51.0)

# %%
import os
import shutil

# Установка исходной и целевой директорий
source_dir = '/content/font_recognition/fonts'
target_dir = '/content/font_dir'

# Создание целевой папки, если она еще не существует
if not os.path.exists(target_dir):
    os.makedirs(target_dir)

# Перебор папок в исходной директории
for folder_name in os.listdir(source_dir):
    folder_path = os.path.join(source_dir, folder_name)

    # Проверка, что это действительно папка
    if os.path.isdir(folder_path):
        # Перебор файлов в папке
        for filename in os.listdir(folder_path):
            # Проверка, что файл имеет расширение .ttf или .otf
            if filename.endswith('.ttf') or filename.endswith('.otf'):
                # Формирование путей для исходного и целевого файлов
                source_file = os.path.join(folder_path, filename)
                target_file = os.path.join(target_dir, filename)

                # Копирование файла в целевую папку
                shutil.copy(source_file, target_file)
                print(f'Скопирован файл: {filename}')
# Out:
# Скопирован файл: BrassMono-Regular.ttf
# Скопирован файл: BrassMono-Italic.ttf
# Скопирован файл: BrassMono-BoldItalic.ttf
# Скопирован файл: BrassMono-Bold.ttf
# Скопирован файл: better-vcr-5.2.ttf
# Скопирован файл: TanaUncialSP.otf
# Скопирован файл: GhastlyPanicCyr.otf
# Скопирован файл: GaneshaType-Regular.ttf
# Скопирован файл: AlumniSansCollegiateOne-Italic.ttf
# Скопирован файл: AlumniSansCollegiateOne-Regular.ttf
# Скопирован файл: ArefRuqaaInk-Regular.ttf
# Скопирован файл: ArefRuqaaInk-Bold.ttf
# Скопирован файл: Realest-Extended.otf
# Скопирован файл: Aguante-Regular.otf
# Скопирован файл: ambidexter_regular.otf

# %%
import os
import random
from PIL import Image, ImageFont, ImageDraw
from fontTools.ttLib import TTFont

def convert_font_to_txt(font_file):
    font = TTFont(font_file)
    font_name = font['name'].getName(1, 3, 1).toUnicode()
    txt_file = os.path.splitext(font_file)[0] + '.txt'
    with open(txt_file, 'w') as f:
        f.write(font_name)
    return txt_file

def generate_image(font_file, text, size, save_path):
    font = ImageFont.truetype(font_file, size)
    img = Image.new('RGB', (1000, 100), color='white')
    draw = ImageDraw.Draw(img)
    draw.text((10, 10), text, font=font, fill='black')
    img.save(save_path)

def generate_dataset(fonts_dir, output_dir, num_images_per_font, train_ratio=0.8):
    # Создаем выходную папку, если она не существует
    os.makedirs(output_dir, exist_ok=True)

    font_files = [f for f in os.listdir(fonts_dir) if f.endswith('.ttf') or f.endswith('.otf')]
    num_fonts = len(font_files)
    num_train_images = int(num_images_per_font * train_ratio)
    num_test_images = num_images_per_font - num_train_images

    # Создаем папки train и test, если они не существуют
    train_dir = os.path.join(output_dir, 'train')
    os.makedirs(train_dir, exist_ok=True)
    test_dir = os.path.join(output_dir, 'test')
    os.makedirs(test_dir, exist_ok=True)

    for i, font_file in enumerate(font_files):
        font_path = os.path.join(fonts_dir, font_file)
        txt_file = convert_font_to_txt(font_path)
        font_name = os.path.splitext(font_file)[0]

        for j in range(num_train_images):
            text = ''.join(random.choices('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ', k=10))
            save_path = os.path.join(train_dir, f'{font_name}_{j}.jpg')
            generate_image(font_path, text, 80, save_path)

        for j in range(num_test_images):
            text = ''.join(random.choices('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ', k=10))
            save_path = os.path.join(test_dir, f'{font_name}_{j}.jpg')
            generate_image(font_path, text, 80, save_path)

        print(f'Generated images for font {i+1}/{num_fonts}: {font_name}')

# Использования (Переношу файл ttf и otf в font_dir, и создаем файл в output_dir)
fonts_dir = '/content/font_dir'
output_dir = '/content/output_dir'
num_images_per_font = 100

generate_dataset(fonts_dir, output_dir, num_images_per_font)
# Out:
# Generated images for font 1/15: BrassMono-Regular
# Generated images for font 2/15: AlumniSansCollegiateOne-Italic
# Generated images for font 3/15: TanaUncialSP
# Generated images for font 4/15: BrassMono-Italic
# Generated images for font 5/15: ArefRuqaaInk-Regular
# Generated images for font 6/15: better-vcr-5.2
# Generated images for font 7/15: Aguante-Regular
# Generated images for font 8/15: GhastlyPanicCyr
# Generated images for font 9/15: Realest-Extended
# Generated images for font 10/15: ArefRuqaaInk-Bold
# Generated images for font 11/15: BrassMono-BoldItalic
# Generated images for font 12/15: GaneshaType-Regular
# Generated images for font 13/15: AlumniSansCollegiateOne-Regular
# Generated images for font 14/15: BrassMono-Bold
# Generated images for font 15/15: ambidexter_regular

# %%
import os
import shutil

# Задайте путь к вашим папкам с обучающим и тестовым наборами данных
train_data_dir = '/content/output_dir/train'
test_data_dir = '/content/output_dir/test'

# Функция для организации изображений
def organize_images(data_dir):
    for image_name in os.listdir(data_dir):
        # Предположим, что класс можно извлечь до первого символа '_'
        class_name = image_name.split('_')[0]
        # Создаем папку для класса, если она не существует
        class_dir = os.path.join(data_dir, class_name)
        if not os.path.exists(class_dir):
            os.makedirs(class_dir)
        # Полный путь к исходному изображению
        src_image_path = os.path.join(data_dir, image_name)
        # Полный путь к целевой папке для перемещения
        dst_image_path = os.path.join(class_dir, image_name)
        # Перемещаем файл
        shutil.move(src_image_path, dst_image_path)

# Организация обучающего набора данных
organize_images(train_data_dir)

# Организация тестового набора данных
organize_images(test_data_dir)

print("Organizing images by class is complete.")
# Out:
# Organizing images by class is complete.

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from PIL import Image

# Проверка обучающей выборки
train_dir = train_data_dir
for class_name in os.listdir(train_dir):
    class_dir = os.path.join(train_dir, class_name)
    if os.path.isdir(class_dir):
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)
            try:
                image = Image.open(image_path)
                print(f"Успешно открыто изображение: {image_path}")
            except Exception as e:
                print(f"Ошибка при открытии изображения {image_path}: {e}")

# Проверка обучающей выборки
test_dir = test_data_dir
for class_name in os.listdir(train_dir):
    class_dir = os.path.join(train_dir, class_name)
    if os.path.isdir(class_dir):
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)
            try:
                image = Image.open(image_path)
                print(f"Успешно открыто изображение: {image_path}")
            except Exception as e:
                print(f"Ошибка при открытии изображения {image_path}: {e}")

# Генерация данных
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Определение архитектуры нейросети
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.Flatten(),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(train_generator.num_classes, activation='softmax')
])

# Компиляция модели
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Обучение модели
epochs = 15
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=test_generator.samples // test_generator.batch_size
)

# Визуализация кривых ошибок
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure()
plt.plot(epochs, acc, 'b', label='Точность на обучающей выборке')
plt.plot(epochs, val_acc, 'r', label='Точность на тестовой выборке')
plt.title('Точность в процессе обучения')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'b', label='Ошибка на обучающей выборке')
plt.plot(epochs, val_loss, 'r', label='Ошибка на тестовой выборке')
plt.title('Ошибка в процессе обучения')
plt.legend()

plt.show()

# Оценка метрик классификации
_, accuracy = model.evaluate(test_generator)
print(f'Точность на тестовой выборке: {accuracy * 100:.2f}%')

# Сохранение модели
model.save('font_recognition_model.h5')
# Out:
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_2.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_50.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_12.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_35.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_1.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_16.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_76.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_20.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_40.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_59.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_63.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_37.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_51.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_46.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_78.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_75.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_23.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_73.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_64.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_47.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_38.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_41.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_57.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_71.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_22.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_49.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_28.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_39.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_62.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_42.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_7.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_3.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_31.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_36.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_13.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_55.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_17.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_43.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_58.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_0.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_56.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_74.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_70.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_67.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_61.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_44.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_30.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_77.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_11.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_4.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_68.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_5.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_72.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_65.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_9.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_79.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_48.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_54.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_14.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_52.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_66.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_19.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_53.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_33.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_34.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_21.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_6.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_18.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_32.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_8.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_10.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_25.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_26.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_60.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_45.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_15.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_69.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_29.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_24.jpg
# Успешно открыто изображение: /content/output_dir/train/ArefRuqaaInk-Regular/ArefRuqaaInk-Regular_27.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_0.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_48.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_57.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_53.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_68.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_28.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_13.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_73.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_44.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_40.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_67.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_54.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_65.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_45.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_61.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_9.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_31.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_3.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_8.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_14.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_42.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_77.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_66.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_72.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_36.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_12.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_59.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_5.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_63.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_49.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_52.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_79.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_55.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_10.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_6.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_15.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_39.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_4.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_19.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_46.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_38.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_29.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_51.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_20.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_60.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_41.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_64.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_70.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_47.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_17.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_30.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_16.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_7.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_34.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_50.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_62.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_24.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_22.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_2.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_58.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_43.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_33.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_74.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold_27.jpg
# Успешно открыто изображение: /content/output_dir/train/BrassMono-Bold/BrassMono-Bold
step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.1322 - val_accuracy: 0.9583
# Epoch 11/15
# 38/38 [==============================] - 111s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9479
# Epoch 12/15
# 38/38 [==============================] - 107s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 0.9549
# Epoch 13/15
# 38/38 [==============================] - 110s 3s/step - loss: 7.7085e-04 - accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9444
# Epoch 14/15
# 38/38 [==============================] - 111s 3s/step - loss: 6.5530e-04 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9514
# Epoch 15/15
# 38/38 [==============================] - 113s 3s/step - loss: 5.0795e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9410
# 10/10 [==============================] - 7s 651ms/step - loss: 0.1856 - accuracy: 0.9433
# Точность на тестовой выборке: 94.33%
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Создаем файл.py - font_recognition, и вставляем код ниже в данный файл.

# %% [markdown]
# Далее код снизу запускаем здесь в Colab

# %%
# !python font_recognition.py /content/font_recognition_model.h5 /content/output_dir/test/better-vcr-5.2/better-vcr-5.2_17.jpg
# Out:
# 2024-04-14 12:57:13.944530: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 12:57:13.944648: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 12:57:13.947983: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-14 12:57:15.241162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 1/1 [==============================] - 0s 156ms/step
# Found 1200 images belonging to 15 classes.
# Предсказанный шрифт: better-vcr-5.2
# Вероятность: 100.00%

# %%
# !python font_recognition.py /content/font_recognition_model.h5 /content/output_dir/test/GaneshaType-Regular/GaneshaType-Regular_13.jpg
# Out:
# 2024-04-14 12:57:26.072667: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 12:57:26.072735: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 12:57:26.074006: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-14 12:57:27.301755: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 1/1 [==============================] - 0s 183ms/step
# Found 1200 images belonging to 15 classes.
# Предсказанный шрифт: GaneshaType-Regular
# Вероятность: 100.00%

# %%
# !python font_recognition.py /content/font_recognition_model.h5 /content/output_dir/test/ArefRuqaaInk-Bold/ArefRuqaaInk-Bold_5.jpg
# Out:
# 2024-04-14 12:57:33.889954: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 12:57:33.890007: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 12:57:33.891275: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-14 12:57:35.117109: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 1/1 [==============================] - 0s 221ms/step
# Found 1200 images belonging to 15 classes.
# Предсказанный шрифт: ArefRuqaaInk-Bold
# Вероятность: 99.94%

# %% [markdown]
# # Создание docker-приложение

# %%
# Установка Docker в Colab
# !apt-get update
# !apt-get install -y docker.io
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [808 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,135 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,176 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,691 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,082 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [44.7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,974 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [61.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,375 kB]
# Fetched 11.6 MB in 2s (5,998 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor bridge-utils containerd dns-root-data dnsmasq-base iptables libip6tc2
#   libnetfilter-conntrack3 libnfnetlink0 libnftnl11 netbase netcat netcat-openbsd pigz runc
#   ubuntu-fan
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ifupdown aufs-tools btrfs-progs cgroupfs-mount
#   | cgroup-lite debootstrap docker-doc rinse zfs-fuse | zfsutils firewalld nftables
# The following NEW packages will be installed:
#   apparmor bridge-utils containerd dns-root-data dnsmasq-base docker.io iptables libip6tc2
#   libnetfilter-conntrack3 libnfnetlink0 libnftnl11 netbase netcat netcat-openbsd pigz runc
#   ubuntu-fan
# 0 upgraded, 17 newly installed, 0 to remove and 46 not upgraded.
# Need to get 71.0 MB of archives.
# After this operation, 273 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 pigz amd64 2.6-1 [63.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 netbase all 6.3 [12.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 netcat-openbsd amd64 1.218-4ubuntu1 [39.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.3 [595 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libip6tc2 amd64 1.8.7-1ubuntu5.2 [20.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnfnetlink0 amd64 1.0.1-3build3 [14.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnetfilter-conntrack3 amd64 1.0.9-1 [45.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnftnl11 amd64 1.2.1-1build1 [65.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 iptables amd64 1.8.7-1ubuntu5.2 [455 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 bridge-utils amd64 1.7-1ubuntu3 [34.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 runc amd64 1.1.7-0ubuntu1~22.04.2 [4,267 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 containerd amd64 1.7.2-0ubuntu1~22.04.1 [36.0 MB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dns-root-data all 2023112702~ubuntu0.22.04.1 [5,136 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dnsmasq-base amd64 2.90-0ubuntu0.22.04.1 [374 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 docker.io amd64 24.0.5-0ubuntu1~22.04.1 [28.9 MB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 netcat all 1.218-4ubuntu1 [2,044 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ubuntu-fan all 0.12.16 [35.2 kB]
# Fetched 71.0 MB in 2s (31.0 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package pigz.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../00-pigz_2.6-1_amd64.deb ...
# Unpacking pigz (2.6-1) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../01-netbase_6.3_all.deb ...
# Unpacking netbase (6.3) ...
# Selecting previously unselected package netcat-openbsd.
# Preparing to unpack .../02-netcat-openbsd_1.218-4ubuntu1_amd64.deb ...
# Unpacking netcat-openbsd (1.218-4ubuntu1) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../03-apparmor_3.0.4-2ubuntu2.3_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.3) ...
# Selecting previously unselected package libip6tc2:amd64.
# Preparing to unpack .../04-libip6tc2_1.8.7-1ubuntu5.2_amd64.deb ...
# Unpacking libip6tc2:amd64 (1.8.7-1ubuntu5.2) ...
# Selecting previously unselected package libnfnetlink0:amd64.
# Preparing to unpack .../05-libnfnetlink0_1.0.1-3build3_amd64.deb ...
# Unpacking libnfnetlink0:amd64 (1.0.1-3build3) ...
# Selecting previously unselected package libnetfilter-conntrack3:amd64.
# Preparing to unpack .../06-libnetfilter-conntrack3_1.0.9-1_amd64.deb ...
# Unpacking libnetfilter-conntrack3:amd64 (1.0.9-1) ...
# Selecting previously unselected package libnftnl11:amd64.
# Preparing to unpack .../07-libnftnl11_1.2.1-1build1_amd64.deb ...
# Unpacking libnftnl11:amd64 (1.2.1-1build1) ...
# Selecting previously unselected package iptables.
# Preparing to unpack .../08-iptables_1.8.7-1ubuntu5.2_amd64.deb ...
# Unpacking iptables (1.8.7-1ubuntu5.2) ...
# Selecting previously unselected package bridge-utils.
# Preparing to unpack .../09-bridge-utils_1.7-1ubuntu3_amd64.deb ...
# Unpacking bridge-utils (1.7-1ubuntu3) ...
# Selecting previously unselected package runc.
# Preparing to unpack .../10-runc_1.1.7-0ubuntu1~22.04.2_amd64.deb ...
# Unpacking runc (1.1.7-0ubuntu1~22.04.2) ...
# Selecting previously unselected package containerd.
# Preparing to unpack .../11-containerd_1.7.2-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking containerd (1.7.2-0ubuntu1~22.04.1) ...
# Selecting previously unselected package dns-root-data.
# Preparing to unpack .../12-dns-root-data_2023112702~ubuntu0.22.04.1_all.deb ...
# Unpacking dns-root-data (2023112702~ubuntu0.22.04.1) ...
# Selecting previously unselected package dnsmasq-base.
# Preparing to unpack .../13-dnsmasq-base_2.90-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking dnsmasq-base (2.90-0ubuntu0.22.04.1) ...
# Selecting previously unselected package docker.io.
# Preparing to unpack .../14-docker.io_24.0.5-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking docker.io (24.0.5-0ubuntu1~22.04.1) ...
# Selecting previously unselected package netcat.
# Preparing to unpack .../15-netcat_1.218-4ubuntu1_all.deb ...
# Unpacking netcat (1.218-4ubuntu1) ...
# Selecting previously unselected package ubuntu-fan.
# Preparing to unpack .../16-ubuntu-fan_0.12.16_all.deb ...
# Unpacking ubuntu-fan (0.12.16) ...
# Setting up libip6tc2:amd64 (1.8.7-1ubuntu5.2) ...
# Setting up netcat-openbsd (1.218-4ubuntu1) ...
# update-alternatives: using /bin/nc.openbsd to provide /bin/nc (nc) in auto mode
# Setting up libnftnl11:amd64 (1.2.1-1build1) ...
# Setting up netcat (1.218-4ubuntu1) ...
# Setting up runc (1.1.7-0ubuntu1~22.04.2) ...
# Setting up dns-root-data (2023112702~ubuntu0.22.04.1) ...
# Setting up apparmor (3.0.4-2ubuntu2.3) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up bridge-utils (1.7-1ubuntu3) ...
# Setting up pigz (2.6-1) ...
# Setting up libnfnetlink0:amd64 (1.0.1-3build3) ...
# Setting up netbase (6.3) ...
# Setting up containerd (1.7.2-0ubuntu1~22.04.1) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/containerd.service → /lib/systemd/system/containerd.service.
# Setting up libnetfilter-conntrack3:amd64 (1.0.9-1) ...
# Setting up iptables (1.8.7-1ubuntu5.2) ...
# update-alternatives: using /usr/sbin/iptables-legacy to provide /usr/sbin/iptables (iptables) in auto mode
# update-alternatives: using /usr/sbin/ip6tables-legacy to provide /usr/sbin/ip6tables (ip6tables) in auto mode
# update-alternatives: using /usr/sbin/iptables-nft to provide /usr/sbin/iptables (iptables) in auto mode
# update-alternatives: using /usr/sbin/ip6tables-nft to provide /usr/sbin/ip6tables (ip6tables) in auto mode
# update-alternatives: using /usr/sbin/arptables-nft to provide /usr/sbin/arptables (arptables) in auto mode
# update-alternatives: using /usr/sbin/ebtables-nft to provide /usr/sbin/ebtables (ebtables) in auto mode
# Setting up docker.io (24.0.5-0ubuntu1~22.04.1) ...
# Adding group `docker' (GID 107) ...
# Done.
# Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /lib/systemd/system/docker.service.
# Created symlink /etc/systemd/system/sockets.target.wants/docker.socket → /lib/systemd/system/docker.socket.
# invoke-rc.d: unknown initscript, /etc/init.d/docker not found.
# invoke-rc.d: could not determine current runlevel
# Setting up dnsmasq-base (2.90-0ubuntu0.22.04.1) ...
# Setting up ubuntu-fan (0.12.16) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/ubuntu-fan.service → /lib/systemd/system/ubuntu-fan.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link

# %%
# Установите BuildX-компонент
# !docker buildx install

# Создайте новый билдер
# !docker buildx create --use

# Соберите Docker-образ с помощью BuildX
# !docker buildx build -t font_recognition .
# Out:
# docker: 'buildx' is not a docker command.
# See 'docker --help'
# unknown flag: --use
# See 'docker --help'.
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   checkpoint  Manage checkpoints
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   config      Manage Swarm configs
#   node        Manage Swarm nodes
#   secret      Manage Swarm secrets
#   service     Manage Swarm services
#   stack       Manage Swarm stacks
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default "/root/.docker")
#   -c, --context string     Name of the context to use to connect to the daemon (overrides DOCKER_HOST env var and default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info", "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default "/root/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default "/root/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default "/root/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#
# unknown shorthand flag: 't' in -t
# See 'docker --help'.
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   checkpoint  Manage checkpoints
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   config      Manage Swarm configs
#   node        Manage Swarm nodes
#   secret      Manage Swarm secrets
#   service     Manage Swarm services
#   stack       Manage Swarm stacks
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default "/root/.docker")
#   -c, --context string     Name of the context to use to connect to the daemon (overrides DOCKER_HOST env var and default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info", "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default "/root/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default "/root/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default "/root/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/

# %%
# !docker buildx build -t font_recognition -f /content/font_recognition_1/Dockerfile .
# Out:
# unknown shorthand flag: 't' in -t
# See 'docker --help'.
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   checkpoint  Manage checkpoints
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   config      Manage Swarm configs
#   node        Manage Swarm nodes
#   secret      Manage Swarm secrets
#   service     Manage Swarm services
#   stack       Manage Swarm stacks
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default "/root/.docker")
#   -c, --context string     Name of the context to use to connect to the daemon (overrides DOCKER_HOST env var and default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info", "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default "/root/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default "/root/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default "/root/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/

# %%
# Запуск Docker daemon
get_ipython().system_raw('/usr/bin/dockerd --host=unix:///var/run/docker.sock --host=tcp://0.0.0.0:2375 --storage-driver=overlay2 &')

# %%
# Запуск контейнера
# Запуск контейнера
# !docker run --gpus all -v /content/font_recognition_model.h5:/path/to/model/checkpoint -v /content/output_dir/test/better-vcr-5.2/better-vcr-5.2_17.jpg:/path/to/image/file font_recognition
# Out:
# docker: Cannot connect to the Docker daemon at unix:///var/run/docker.sock. Is the docker daemon running?.
# See 'docker run --help'.

# %%
# !pip install dockerpty
# !pip install docker-py
# Out:
# Requirement already satisfied: dockerpty in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Requirement already satisfied: six>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from dockerpty) (1.16.0)
# Collecting docker-py
#   Downloading docker_py-1.10.6-py2.py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 1.6 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.2.1 (from docker-py)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: requests!=2.11.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from docker-py) (2.31.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-py) (1.16.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker-py) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests!=2.11.0,>=2.5.2->docker-py) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests!=2.11.0,>=2.5.2->docker-py) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests!=2.11.0,>=2.5.2->docker-py) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests!=2.11.0,>=2.5.2->docker-py) (2024.2.2)
# Installing collected packages: docker-pycreds, docker-py
# Successfully installed docker-py-1.10.6 docker-pycreds-0.4.0

# %%
# !python run_in_docker.py
# Out:
# DEPRECATED: The legacy builder is deprecated and will be removed in a future release.
#             Install the buildx component to build images with BuildKit:
#             https://docs.docker.com/go/buildx/
#
# unable to prepare context: unable to evaluate symlinks in Dockerfile path: lstat /content/Dockerfile: no such file or directory
# docker: Cannot connect to the Docker daemon at unix:///var/run/docker.sock. Is the docker daemon running?.
# See 'docker run --help'.
# INFO[2024-04-14T13:42:50.831537712Z] Starting up
# WARN[2024-04-14T13:42:50.832120512Z] Binding to IP address without --tlsverify is insecure and gives root access on this machine to everyone who has access to your network.  host="tcp://0.0.0.0:2375"
# WARN[2024-04-14T13:42:50.832168579Z] Binding to an IP address, even on localhost, can also give access to scripts run in a browser. Be safe out there!  host="tcp://0.0.0.0:2375"
# WARN[2024-04-14T13:42:51.832335631Z] Binding to an IP address without --tlsverify is deprecated. Startup is intentionally being slowed down to show this message  host="tcp://0.0.0.0:2375"
# WARN[2024-04-14T13:42:51.832399746Z] Please consider generating tls certificates with client validation to prevent exposing unauthenticated root access to your network  host="tcp://0.0.0.0:2375"
# WARN[2024-04-14T13:42:51.832416505Z] You can override this by explicitly specifying '--tls=false' or '--tlsverify=false'  host="tcp://0.0.0.0:2375"
# WARN[2024-04-14T13:42:51.832436665Z] Support for listening on TCP without authentication or explicit intent to run without authentication will be removed in the next release  host="tcp://0.0.0.0:2375"
# INFO[2024-04-14T13:43:06.838448279Z] containerd not running, starting managed containerd
# INFO[2024-04-14T13:43:06.839509953Z] started new containerd process                address=/var/run/docker/containerd/containerd.sock module=libcontainerd pid=25508
# INFO[2024-04-14T13:43:06.867941016Z] starting containerd                           revision= version=1.7.2
# INFO[2024-04-14T13:43:06.891408525Z] loading plugin "io.containerd.snapshotter.v1.aufs"...  type=io.containerd.snapshotter.v1
# INFO[2024-04-14T13:43:06.895231265Z] skip loading plugin "io.containerd.snapshotter.v1.aufs"...  error="aufs is not supported (modprobe aufs failed: exit status 1 \"modprobe: FATAL: Module aufs not found in directory /lib/modules/6.1.58+\\n\"): skip plugin" type=io.containerd.snapshotter.v1
# INFO[2024-04-14T13:43:06.895629949Z] loading plugin "io.containerd.snapshotter.v1.btrfs"...  type=io.containerd.snapshotter.v1
# INFO[2024-04-14T13:43:06.896021098Z] skip loading plugin "io.containerd.snapshotter.v1.btrfs"...  error="path /var/lib/docker/containerd/daemon/io.containerd.snapshotter.v1.btrfs (overlay) must be a btrfs filesystem to be used with the btrfs snapshotter: skip plugin" type=io.containerd.snapshotter.v1
# INFO[2024-04-14T13:43:06.896133122Z] loading plugin "io.containerd.content.v1.content"...  type=io.containerd.content.v1
# INFO[2024-04-14T13:43:06.896202270Z] loading plugin "io.containerd.snapshotter.v1.native"...  type=io.containerd.snapshotter.v1
# INFO[2024-04-14T13:43:06.896678977Z] loading plugin "io.containerd.snapshotter.v1.overlayfs"...  type=io.containerd.snapshotter.v1
# INFO[2024-04-14T13:43:06.896918754Z] loading plugin "io.containerd.snapshotter.v1.devmapper"...  type=io.containerd.snapshotter.v1
# WARN[2024-04-14T13:43:06.896986612Z] failed to load plugin io.containerd.snapshotter.v1.devmapper  error="devmapper not configured"
# INFO[2024-04-14T13:43:06.897029653Z] loading plugin "io.containerd.snapshotter.v1.zfs"...  type=io.containerd.snapshotter.v1
# INFO[2024-04-14T13:43:06.897224969Z] skip loading plugin "io.containerd.snapshotter.v1.zfs"...  error="path /var/lib/docker/containerd/daemon/io.containerd.snapshotter.v1.zfs must be a zfs filesystem to be used with the zfs snapshotter: skip plugin" type=io.containerd.snapshotter.v1
# INFO[2024-04-14T13:43:06.897763721Z] loading plugin "io.containerd.metadata.v1.bolt"...  type=io.containerd.metadata.v1
# WARN[2024-04-14T13:43:06.897814667Z] could not use snapshotter devmapper in metadata plugin  error="devmapper not configured"
# INFO[2024-04-14T13:43:06.897839954Z] metadata content store policy set             policy=shared
# INFO[2024-04-14T13:43:06.898109151Z] loading plugin "io.containerd.differ.v1.walking"...  type=io.containerd.differ.v1
# INFO[2024-04-14T13:43:06.898152617Z] loading plugin "io.containerd.event.v1.exchange"...  type=io.containerd.event.v1
# INFO[2024-04-14T13:43:06.898182055Z] loading plugin "io.containerd.gc.v1.scheduler"...  type=io.containerd.gc.v1
# INFO[2024-04-14T13:43:06.898236423Z] loading plugin "io.containerd.lease.v1.manager"...  type=io.containerd.lease.v1
# INFO[2024-04-14T13:43:06.898267533Z] loading plugin "io.containerd.nri.v1.nri"...  type=io.containerd.nri.v1
# INFO[2024-04-14T13:43:06.898303813Z] NRI interface is disabled by configuration.
# INFO[2024-04-14T13:43:06.898325710Z] loading plugin "io.containerd.runtime.v2.task"...  type=io.containerd.runtime.v2
# INFO[2024-04-14T13:43:06.898425465Z] loading plugin "io.containerd.runtime.v2.shim"...  type=io.containerd.runtime.v2
# INFO[2024-04-14T13:43:06.898458531Z] loading plugin "io.containerd.sandbox.store.v1.local"...  type=io.containerd.sandbox.store.v1
# INFO[2024-04-14T13:43:06.898487630Z] loading plugin "io.containerd.sandbox.controller.v1.local"...  type=io.containerd.sandbox.controller.v1
# INFO[2024-04-14T13:43:06.898516526Z] loading plugin "io.containerd.streaming.v1.manager"...  type=io.containerd.streaming.v1
# INFO[2024-04-14T13:43:06.898547795Z] loading plugin "io.containerd.service.v1.introspection-service"...  type=io.containerd.service.v1
# INFO[2024-04-14T13:43:06.898575219Z] loading plugin "io.containerd.service.v1.containers-service"...  type=io.containerd.service.v1
# INFO[2024-04-14T13:43:06.898602017Z] loading plugin "io.containerd.service.v1.content-service"...  type=io.containerd.service.v1
# INFO[2024-04-14T13:43:06.898630169Z] loading plugin "io.containerd.service.v1.diff-service"...  type=io.containerd.service.v1
# INFO[2024-04-14T13:43:06.898657852Z] loading plugin "io.containerd.service.v1.images-service"...  type=io.containerd.service.v1
# INFO[2024-04-14T13:43:06.898684420Z] loading plugin "io.containerd.service.v1.namespaces-service"...  type=io.containerd.service.v1
# INFO[2024-04-14T13:43:06.898727981Z] loading plugin "io.containerd.service.v1.snapshots-service"...  type=io.containerd.service.v1
# INFO[2024-04-14T13:43:06.898754578Z] loading plugin "io.containerd.runtime.v1.linux"...  type=io.containerd.runtime.v1
# INFO[2024-04-14T13:43:06.898837869Z] loading plugin "io.containerd.monitor.v1.cgroups"...  type=io.containerd.monitor.v1
# INFO[2024-04-14T13:43:06.899252201Z] loading plugin "io.containerd.service.v1.tasks-service"...  type=io.containerd.service.v1
# INFO[2024-04-14T13:43:06.899309158Z] loading plugin "io.containerd.grpc.v1.introspection"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899342935Z] loading plugin "io.containerd.transfer.v1.local"...  type=io.containerd.transfer.v1
# INFO[2024-04-14T13:43:06.899385081Z] loading plugin "io.containerd.internal.v1.restart"...  type=io.containerd.internal.v1
# INFO[2024-04-14T13:43:06.899478705Z] loading plugin "io.containerd.grpc.v1.containers"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899510093Z] loading plugin "io.containerd.grpc.v1.content"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899547568Z] loading plugin "io.containerd.grpc.v1.diff"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899574557Z] loading plugin "io.containerd.grpc.v1.events"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899600321Z] loading plugin "io.containerd.grpc.v1.healthcheck"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899625399Z] loading plugin "io.containerd.grpc.v1.images"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899651737Z] loading plugin "io.containerd.grpc.v1.leases"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899676279Z] loading plugin "io.containerd.grpc.v1.namespaces"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899738310Z] loading plugin "io.containerd.internal.v1.opt"...  type=io.containerd.internal.v1
# INFO[2024-04-14T13:43:06.899804794Z] loading plugin "io.containerd.grpc.v1.sandbox-controllers"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899834984Z] loading plugin "io.containerd.grpc.v1.sandboxes"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899859967Z] loading plugin "io.containerd.grpc.v1.snapshots"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899884441Z] loading plugin "io.containerd.grpc.v1.streaming"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899918441Z] loading plugin "io.containerd.grpc.v1.tasks"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899946590Z] loading plugin "io.containerd.grpc.v1.transfer"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.899978246Z] loading plugin "io.containerd.grpc.v1.version"...  type=io.containerd.grpc.v1
# INFO[2024-04-14T13:43:06.900004251Z] loading plugin "io.containerd.tracing.processor.v1.otlp"...  type=io.containerd.tracing.processor.v1
# INFO[2024-04-14T13:43:06.900038026Z] skip loading plugin "io.containerd.tracing.processor.v1.otlp"...  error="no OpenTelemetry endpoint: skip plugin" type=io.containerd.tracing.processor.v1
# INFO[2024-04-14T13:43:06.900060923Z] loading plugin "io.containerd.internal.v1.tracing"...  type=io.containerd.internal.v1
# INFO[2024-04-14T13:43:06.900081843Z] skipping tracing processor initialization (no tracing plugin)  error="no OpenTelemetry endpoint: skip plugin"
# INFO[2024-04-14T13:43:06.900876765Z] serving...                                    address=/var/run/docker/containerd/containerd-debug.sock
# INFO[2024-04-14T13:43:06.901058078Z] serving...                                    address=/var/run/docker/containerd/containerd.sock.ttrpc
# INFO[2024-04-14T13:43:06.901173102Z] serving...                                    address=/var/run/docker/containerd/containerd.sock
# INFO[2024-04-14T13:43:06.901634285Z] containerd successfully booted in 0.034444s
# INFO[2024-04-14T13:43:06.919349524Z] [graphdriver] trying configured driver: vfs
# INFO[2024-04-14T13:43:06.919688816Z] Loading containers: start.
# INFO[2024-04-14T13:43:06.921748745Z] unable to detect if iptables supports xlock: 'iptables --wait -L -n': `# Warning: iptables-legacy tables present, use iptables-legacy to see them
# iptables v1.8.7 (nf_tables): Could not fetch rule set generation id: Permission denied (you must be root)`  error="exit status 4"
# INFO[2024-04-14T13:43:06.944872962Z] stopping event stream following graceful shutdown  error="<nil>" module=libcontainerd namespace=moby
# INFO[2024-04-14T13:43:06.945309923Z] stopping event stream following graceful shutdown  error="context canceled" module=libcontainerd namespace=plugins.moby
# INFO[2024-04-14T13:43:06.945352977Z] stopping healthcheck following graceful shutdown  module=libcontainerd
# failed to start daemon: Error initializing network controller: error obtaining controller instance: failed to create NAT chain DOCKER: iptables failed: iptables -t nat -N DOCKER: iptables v1.8.7 (nf_tables): Could not fetch rule set generation id: Permission denied (you must be root)
#
#  (exit status 4)
